# %% [markdown]
# Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd

# %%
df=pd.read_csv("Services.csv")

# %%
df.head()
#shows first 5 row data of dataframe
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.tail()
#last rows
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
#describes the stats but only describes whose data type is int or float
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
df.columns
#shows the index of column
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes== object].index]
#shows the dataframes of only object type data
# Out:
#            accepted_payments         alternate_name  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# 5                        NaN                    NaN
# 6                        NaN                    NaN
# 7                        NaN                    NaN
# 8                        NaN                    NaN
# 9                        NaN                    NaN
# 10                       NaN                    NaN
# 11                       NaN                    NaN
# 12                       NaN                    NaN
# 13                       NaN                    NaN
# 14                       NaN                    NaN
# 15                       NaN                    NaN
# 16                       NaN                    NaN
# ...

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
Mylist=[['Ampere','Borde','Chartered'],['Amputate','Born','Compensate'],['Aviation','Bookmark','Clone'],['Aftermath','Benchmark','Copyright']]

# %%
Mylist
# Out:
# [['Ampere', 'Borde', 'Chartered'],
#  ['Amputate', 'Born', 'Compensate'],
#  ['Aviation', 'Bookmark', 'Clone'],
#  ['Aftermath', 'Benchmark', 'Copyright']]

# %%
df=pd.DataFrame(Mylist,columns=['A','B','C'])

# %%
df
# Out:
#            A          B           C
# 0     Ampere      Borde   Chartered
# 1   Amputate       Born  Compensate
# 2   Aviation   Bookmark       Clone
# 3  Aftermath  Benchmark   Copyright

# %%
inc_list = []
for i in range(0,9):
    if i%2!=0:
        inc_list.append(i)

# %%
inc_list
# Out:
# [1, 3, 5, 7]

# %%
da = df['A']
db = df['B']
dc = df['C']

# %%
da,db,dc
# Out:
# (0       Ampere
#  1     Amputate
#  2     Aviation
#  3    Aftermath
#  Name: A, dtype: object,
#  0        Borde
#  1         Born
#  2     Bookmark
#  3    Benchmark
#  Name: B, dtype: object,
#  0     Chartered
#  1    Compensate
#  2         Clone
#  3     Copyright
#  Name: C, dtype: object)

# %%
d2=pd.Series(list(da),index=inc_list)
d3=pd.Series(list(db),index=inc_list)
d4=pd.Series(list(dc),index=inc_list)

# %%
d2
# Out:
# 1       Ampere
# 3     Amputate
# 5     Aviation
# 7    Aftermath
# dtype: object

# %%
d3
# Out:
# 1        Borde
# 3         Born
# 5     Bookmark
# 7    Benchmark
# dtype: object

# %%
d4
# Out:
# 1     Chartered
# 3    Compensate
# 5         Clone
# 7     Copyright
# dtype: object

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Values':[12,15,17,19,15]})

# %%
d2=df['Values']

# %%
def values(list):
    l2=sum(d2[0:3])
    print(l2)

# %%
values(d2)
# Out:
# 44

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df = pd.DataFrame({'Text':['Amitoj','Amitoj Makes new music','Gaming is my new style but I make gaming music too']})
#creating the dataframe

# %%
df
# Out:
#                                                 Text
# 0                                             Amitoj
# 1                             Amitoj Makes new music
# 2  Gaming is my new style but I make gaming music...

# %%
df['Word_Count']=df['Text'].apply(lambda x:len(x.split()))
#function for counting words

# %%
df
# Out:
#                                                 Text  Word_Count
# 0                                             Amitoj           1
# 1                             Amitoj Makes new music           4
# 2  Gaming is my new style but I make gaming music...          11

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# DataFrame.size() : It shows the the multiplication of number of rows and columns present in the dataframe
# DataFrame.size() : It shows both no. of rows as well as number of columns present in the dataframe

# %%
df1 = {
     'Name':['Amitoj','Andrea','micheal','moris','Ravi','Xien','Jalpa','Zilpe'],
   'Mathematics_score':[62,47,55,74,32,77,86,55]}

# %%
df=pd.DataFrame(df1)

# %%
df
# Out:
#       Name  Mathematics_score
# 0   Amitoj                 62
# 1   Andrea                 47
# 2  micheal                 55
# 3    moris                 74
# 4     Ravi                 32
# 5     Xien                 77
# 6    Jalpa                 86
# 7    Zilpe                 55

# %%
df.shape
# Out:
# (8, 2)

# %%
df.size
# Out:
# 16

# %% [markdown]
# # Q6. Which function of pandas do we use to read an excel file?

# %%
#the function we use for reading excelfile is pd.read_csv("<Name of the file>.csv")
pd.read_csv('Services.csv')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %% [markdown]
# # Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.

# %%
us_1 = pd.DataFrame({'Email':['johndoe@gmail.com','amit@hotmal.com','djhype@tocmail.com']})

# %%
us_1
# Out:
#                 Email
# 0   johndoe@gmail.com
# 1     amit@hotmal.com
# 2  djhype@tocmail.com

# %%
def sep(x):
    return x.split('@')[0]

# %%
us_1['Username']=us_1['Email'].apply(sep)

# %%
us_1
# Out:
#                 Email Username
# 0   johndoe@gmail.com  johndoe
# 1     amit@hotmal.com     amit
# 2  djhype@tocmail.com   djhype

# %% [markdown]
# # Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows.

# %%
import pandas as pd
df = pd.DataFrame({'A':[3,8,6,2,9],'B':[5,2,9,3,1],'C':[1,7,4,5,2]})

# %%
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
def filt_num(df):
    selected_rows = df[(df['A']>5) & (df['B']<10)]
    return selected_rows

# %%
filt_num(df)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# # Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,median, and standard deviation of the values in the 'Values' column.

# %%
df=pd.DataFrame({'Values':[1,4,6,5,4,2,4,6,7,9,45,65]})

# %%
df
# Out:
#     Values
# 0        1
# 1        4
# 2        6
# 3        5
# 4        4
# 5        2
# 6        4
# 7        6
# 8        7
# 9        9
# 10      45
# 11      65

# %%
def stats_of(df):
    print("Median: ",df.median())
    print("Mean : ",df.mean())
    print("Std Deviation: ",df.std())

# %%
stats_of(df)
# Out:
# Median:  Values    5.5
# dtype: float64
# Mean :  Values    13.166667
# dtype: float64
# Std Deviation:  Values    20.112562
# dtype: float64

# %%
dm=pd.DataFrame({'Values':[12,44,66,54,64,42,4,6,7,9,45,65]})
dm
# Out:
#     Values
# 0       12
# 1       44
# 2       66
# 3       54
# 4       64
# 5       42
# 6        4
# 7        6
# 8        7
# 9        9
# 10      45
# 11      65

# %%
stats_of(dm)
# Out:
# Median:  Values    43.0
# dtype: float64
# Mean :  Values    34.833333
# dtype: float64
# Std Deviation:  Values    25.376558
# dtype: float64

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
date=pd.date_range(start='2023-08-23',end='2023-08-29')

# %%
date
# Out:
# DatetimeIndex(['2023-08-23', '2023-08-24', '2023-08-25', '2023-08-26',
#                '2023-08-27', '2023-08-28', '2023-08-29'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame({'Sales':[24,35,65,76,87,56,44],'Date':date,})

# %%
df
# Out:
#    Sales       Date
# 0     24 2023-06-23
# 1     35 2023-06-24
# 2     65 2023-06-25
# 3     76 2023-06-26
# 4     87 2023-06-27
# 5     56 2023-06-28
# 6     44 2023-06-29

# %%
df['Sales'].rolling(window=7).mean()
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6    55.285714
# Name: Sales, dtype: float64

# %% [markdown]
# # Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g. Monday, Tuesday) corresponding to each date in the 'Date' column.

# %%
date = pd.date_range(start='2023-01-01',end='2023-01-05')

# %%
df=pd.DataFrame({'Date':date})

# %%
df
# Out:
#         Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05

# %%
weekname=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

# %%
df['Weekday']=df['Date'].dt.weekday

# %%
df
# Out:
#         Date  Weekday
# 0 2023-01-01        6
# 1 2023-01-02        0
# 2 2023-01-03        1
# 3 2023-01-04        2
# 4 2023-01-05        3

# %%
df['Weekday']=df['Weekday'].map({0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday',5:'Saturday',6:'Sunday'})

# %%
df
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# # Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
date=pd.date_range(start='2022--01',end='2023-02-10')

# %%
df=pd.DataFrame({'Date': date})

# %%
df
# Out:
#          Date
# 0  2022-12-01
# 1  2022-12-02
# 2  2022-12-03
# 3  2022-12-04
# 4  2022-12-05
# ..        ...
# 67 2023-02-06
# 68 2023-02-07
# 69 2023-02-08
# 70 2023-02-09
# 71 2023-02-10
#
# [72 rows x 1 columns]

# %%
def filter_date(df,start_date,end_date):
    df['Date']=pd.to_datetime(df['Date'])
    td=pd.Timedelta(days=1,hours=4)
    selected_rows=df[(df['Date']>=start_date) & (df['Date']<=end_date)]
    return selected_rows+td

# %%
filter_date(df,'2023-01-01','2023-01-31')
# Out:
#                   Date
# 31 2023-01-02 04:00:00
# 32 2023-01-03 04:00:00
# 33 2023-01-04 04:00:00
# 34 2023-01-05 04:00:00
# 35 2023-01-06 04:00:00
# 36 2023-01-07 04:00:00
# 37 2023-01-08 04:00:00
# 38 2023-01-09 04:00:00
# 39 2023-01-10 04:00:00
# 40 2023-01-11 04:00:00
# 41 2023-01-12 04:00:00
# 42 2023-01-13 04:00:00
# 43 2023-01-14 04:00:00
# 44 2023-01-15 04:00:00
# 45 2023-01-16 04:00:00
# 46 2023-01-17 04:00:00
# 47 2023-01-18 04:00:00
# 48 2023-01-19 04:00:00
# 49 2023-01-20 04:00:00
# 50 2023-01-21 04:00:00
# 51 2023-01-22 04:00:00
# 52 2023-01-23 04:00:00
# 53 2023-01-24 04:00:00
# 54 2023-01-25 04:00:00
# 55 2023-01-26 04:00:00
# 56 2023-01-27 04:00:00
# 57 2023-01-28 04:00:00
# 58 2023-01-29 04:00:00
# 59 2023-01-30 04:00:00
# 60 2023-01-31 04:00:00
# 61 2023-02-01 04:00:00

# %% [markdown]
# # Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?

# %% [markdown]
# It is necessary that we import pandas library by entering this given function: "import pandas as pd"
